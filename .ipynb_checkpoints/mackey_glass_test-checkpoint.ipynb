# %%
#!/usr/bin/python

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

# import os
# import sys
import numpy as np

import time

from reservoir import Reservoir
import data

# %load_ext autoreload
# %autoreload 1
# %aimport data
# %aimport reservoir

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
total_pred_steps = 10
each_pred_step = 1
enc_depth = 10
n_res = 200
forget=100
b = Reservoir(n_res=n_res, input_scale=2, train_method='ridge', train_param=5,
              weights_type='complex gaussian', random_projection='simulation',
              activation_fun='binary', activation_param=1,encoding_method='naivebinary', 
              encoding_param=1, encoded_spatial_points=1, forget=forget, 
              total_pred_steps = total_pred_steps, each_pred_step = each_pred_step) 
# if DMD: encoded_spatial_points = 2**enc_depth
# if SLM: encoded_spatial_points = 1

# %%
input_data = data.mackey_glass(n_sequence=10, sequence_length=4000)
y = data.roll_and_concat(input_data, roll_num=each_pred_step)
input_data = input_data[:,:-10*each_pred_step,:]
y = y[:,:-10*each_pred_step,:]
b.fit(input_data, y)
# Out:
# Start of training...
# Initialization finished. Elapsed time:
# 0.0034646987915039062
# 100%|██████████| 3990/3990 [00:00<00:00, 8812.61it/s]
# 100%|██████████| 3990/3990 [00:00<00:00, 9027.14it/s]
# 100%|██████████| 3990/3990 [00:00<00:00, 8961.38it/s]
# 100%|██████████| 3990/3990 [00:00<00:00, 9040.14it/s]
# 100%|██████████| 3990/3990 [00:00<00:00, 8588.59it/s]
# 100%|██████████| 3990/3990 [00:00<00:00, 8999.07it/s]
# 100%|██████████| 3990/3990 [00:00<00:00, 9197.88it/s]
# 100%|██████████| 3990/3990 [00:00<00:00, 8382.99it/s]
# 100%|██████████| 3990/3990 [00:00<00:00, 9192.38it/s]
# 100%|██████████| 3990/3990 [00:00<00:00, 8963.35it/s]
# (10, 3890, 402)
# Iterations finished. Elapsed time:
# 4.645833730697632
# Training finished. Elapsed time:
# 4.8603246212005615
# Training score:
# 0.14431728949938705
# Reservoir(activation_fun='phase', activation_param=1, each_pred_step=1,
#      encoded_spatial_points=1, encoding_method='phase', encoding_param=1,
#      forget=100, input_scale=2, n_res=200, opu_transform=None,
#      random_projection='simulation',
#      random_state=<mtrand.RandomState object at 0x7f12617549d8>,
#      res_scale=1, save=0, total_pred_steps=10, train_method='ridge',
#      train_param=5, verbose=1, weights_type='complex gaussian')

# %%
input_data = data.mackey_glass(sequence_length=2000)
y = data.roll_and_concat(input_data, roll_num=total_pred_steps)[:, b.forget:, :]
y = y.reshape(-1, y.shape[-1])
input_data = input_data[:,forget:-10*each_pred_step,:]
y = y[forget:-10*each_pred_step,:]
pred_output, valid_score = b.score(input_data, y)
# Out:
# Start of testing...
# Initialization finished. Elapsed time:
# 0.00046539306640625
# 100%|██████████| 1890/1890 [00:00<00:00, 9793.54it/s]
# (1, 1890, 402)
# Iterations finished. Elapsed time:
# 0.19725346565246582
# Initialization finished. Elapsed time:
# 0.00030922889709472656
# 100%|██████████| 1890/1890 [00:00<00:00, 9486.48it/s]
# (1, 1890, 402)
# Iterations finished. Elapsed time:
# 0.20261096954345703
# Initialization finished. Elapsed time:
# 0.0003330707550048828
# 100%|██████████| 1890/1890 [00:00<00:00, 9928.08it/s]
# (1, 1890, 402)
# Iterations finished. Elapsed time:
# 0.20180368423461914
# Initialization finished. Elapsed time:
# 0.0003814697265625
# 100%|██████████| 1890/1890 [00:00<00:00, 8361.45it/s]
# (1, 1890, 402)
# Iterations finished. Elapsed time:
# 0.23760414123535156
# Initialization finished. Elapsed time:
# 0.00035834312438964844
# 100%|██████████| 1890/1890 [00:00<00:00, 7942.02it/s]
# (1, 1890, 402)
# Iterations finished. Elapsed time:
# 0.25162220001220703
# Initialization finished. Elapsed time:
# 0.0003337860107421875
# 100%|██████████| 1890/1890 [00:00<00:00, 9047.61it/s]
# (1, 1890, 402)
# Iterations finished. Elapsed time:
# 0.223829984664917
# Initialization finished. Elapsed time:
# 0.00031566619873046875
# 100%|██████████| 1890/1890 [00:00<00:00, 8742.79it/s]
# (1, 1890, 402)
# Iterations finished. Elapsed time:
# 0.220231294631958
# Initialization finished. Elapsed time:
# 0.00043392181396484375
# 100%|██████████| 1890/1890 [00:00<00:00, 5483.86it/s]
# (1, 1890, 402)
# Iterations finished. Elapsed time:
# 0.3592865467071533
# Initialization finished. Elapsed time:
# 0.0003631114959716797
# 100%|██████████| 1890/1890 [00:00<00:00, 5548.67it/s]
# (1, 1890, 402)
# Iterations finished. Elapsed time:
# 0.3543398380279541
# Initialization finished. Elapsed time:
# 0.00035572052001953125
# 100%|██████████| 1890/1890 [00:00<00:00, 7937.03it/s]
# (1, 1890, 402)
# Iterations finished. Elapsed time:
# 0.250154972076416
# Testing finished. Elapsed time:
# 2.536646604537964
# Testing finished. Elapsed time:
# 4.8603246212005615
# Testing score:
# -0.15641521023200644

# %%
# n_input = round(pred_output.shape[0]/2)-100
n_input = 1000
all_data = np.concatenate((y[:n_input, 0], pred_output[n_input, :total_pred_steps]))
plt.figure(1)
plt.plot(all_data)
plt.plot(y[0:n_input+total_pred_steps, 0])
plt.show()
plt.figure(2)
plt.plot(y[0:n_input+total_pred_steps, 0]-all_data)
# plt.plot(np.linspace(n_input,n_input,100),np.linspace(-0.6,0.6,100))
plt.show()

# %%
# maximum first 5 prediction steps are illustrated 
pred_step = min(5, y.shape[-1])
fig, axs = plt.subplots(pred_step, 1, sharex=True, figsize=(10,10))
fig.subplots_adjust(hspace=0)
for i in range(pred_step):
    axs[i].plot(y[:,i])
    axs[i].plot(pred_output[:,i])
    axs[i].plot(y[:,i]-pred_output[:,i])
plt.show()

# %%
# maximum first 5 prediction steps are illustrated 
pred_step = min(5, y.shape[-1])
fig, axs = plt.subplots(pred_step, 1, sharex=True, figsize=(10,10))
fig.subplots_adjust(hspace=0)
for i in range(pred_step):
    axs[i].plot(y[:,i])
    axs[i].plot(pred_output[:,i])
plt.show()

# %%
# rms for binary encoding

length_input = pred_output.shape[0]-total_pred_steps
rms = np.zeros((length_input, total_pred_steps))
for n_input in range(1, length_input):
    for n_pred in range(1, total_pred_steps):
        d1 = pred_output[n_input, :n_pred]
        d2 = y[n_input:n_input+n_pred, 0]
        rms[n_input, n_pred] = np.sqrt(1./(n_pred)*np.sum((d1 - d2)**2))

plt.figure(1,figsize=(10,2))
plt.title('rms')
plt.ylabel('input length')
plt.xlabel('Prediction length')
im=plt.pcolormesh(rms[:,:], cmap='gist_heat')
plt.colorbar(im)
plt.show;

plt.figure(2,figsize=(8.1,2))
plt.ylabel('average rms by input length')
plt.xlabel('Prediction length')
plt.plot(np.sum(rms[:,:], axis=0)/length_input)
plt.show;

# %%
plt.figure(2,figsize=(8.1,2))
plt.ylabel('average rms by input length')
plt.xlabel('Prediction length')
plt.plot(np.sum(rms[1:,:], axis=1)/total_pred_steps)
plt.show;
