# %%
#!/usr/bin/python

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

# import os
# import sys
import numpy as np

import time

from reservoir import Reservoir
import data

# %load_ext autoreload
# %autoreload 1
# %aimport data
# %aimport reservoir

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
total_pred_steps = 100
enc_depth = 10
n_res = 800
forget=100
b = Reservoir(n_res=n_res, input_scale=2, train_method='ridge', train_param=2000,
              weights_type='complex gaussian', random_projection='simulation',
              activation_fun='binary', activation_param=1,encoding_method='naivebinary', 
              encoding_param=1, encoded_spatial_points=2**enc_depth, forget=forget, 
              total_pred_steps = total_pred_steps, each_pred_step = 1) 
# if DMD: encoded_spatial_points = 2**enc_depth
# if SLM: encoded_spatial_points = spatial_points+1

# %%
input_data = data.mackey_glass(sequence_length=1000)
y = data.roll_and_concat(input_data, roll_num=1)
# input_data = input_data[:,:-roll_num,:]
# y = y[:,:-roll_num,:]
b.fit(input_data, y)
# Out:
# Start of training...
# Initialization finished. Elapsed time:
# 0.009800434112548828
# 100%|██████████| 1000/1000 [00:01<00:00, 976.39it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.049644947052002
# Training finished. Elapsed time:
# 1.3134236335754395
# Training score:
# 0.971257729561974
# Reservoir(activation_fun='binary', activation_param=1, each_pred_step=1,
#      encoded_spatial_points=1024, encoding_method='naivebinary',
#      encoding_param=1, forget=100, input_scale=2, n_res=800,
#      opu_transform=None, random_projection='simulation',
#      random_state=<mtrand.RandomState object at 0x7f287f155948>,
#      res_scale=1, save=0, total_pred_steps=100, train_method='ridge',
#      train_param=2000, verbose=1, weights_type='complex gaussian')

# %%
input_data = data.mackey_glass(sequence_length=1000)
y = data.roll_and_concat(input_data, roll_num=total_pred_steps)[:, b.forget:, :]
y = y.reshape(-1, y.shape[-1])
pred_output, valid_score = b.score(input_data, y)
# Out:
# Start of testing...
# Initialization finished. Elapsed time:
# 0.01306605339050293
# 100%|██████████| 1000/1000 [00:01<00:00, 963.69it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.067718744277954
# Initialization finished. Elapsed time:
# 0.011357545852661133
# 100%|██████████| 900/900 [00:01<00:00, 869.46it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.0653281211853027
# Initialization finished. Elapsed time:
# 0.01134490966796875
# 100%|██████████| 900/900 [00:00<00:00, 1002.23it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.9258236885070801
# Initialization finished. Elapsed time:
# 0.011602163314819336
# 100%|██████████| 900/900 [00:01<00:00, 735.81it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.2458651065826416
# Initialization finished. Elapsed time:
# 0.013267993927001953
# 100%|██████████| 900/900 [00:01<00:00, 689.52it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.340815782546997
# Initialization finished. Elapsed time:
# 0.011913061141967773
# 100%|██████████| 900/900 [00:00<00:00, 1090.88it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.8569722175598145
# Initialization finished. Elapsed time:
# 0.011459589004516602
# 100%|██████████| 900/900 [00:00<00:00, 1005.86it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.9147942066192627
# Initialization finished. Elapsed time:
# 0.011288166046142578
# 100%|██████████| 900/900 [00:01<00:00, 753.93it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.2230472564697266
# Initialization finished. Elapsed time:
# 0.016578197479248047
# 100%|██████████| 900/900 [00:02<00:00, 439.21it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 2.0772080421447754
# Initialization finished. Elapsed time:
# 0.020206689834594727
# 100%|██████████| 900/900 [00:02<00:00, 380.66it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 2.4035890102386475
# Initialization finished. Elapsed time:
# 0.016442537307739258
# 100%|██████████| 900/900 [00:01<00:00, 891.08it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.0356488227844238
# Initialization finished. Elapsed time:
# 0.017856597900390625
# 100%|██████████| 900/900 [00:01<00:00, 670.32it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.3813769817352295
# Initialization finished. Elapsed time:
# 0.015517473220825195
# 100%|██████████| 900/900 [00:01<00:00, 718.69it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.2831182479858398
# Initialization finished. Elapsed time:
# 0.012139081954956055
# 100%|██████████| 900/900 [00:01<00:00, 618.14it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.4824540615081787
# Initialization finished. Elapsed time:
# 0.024002552032470703
# 100%|██████████| 900/900 [00:01<00:00, 853.62it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.1024320125579834
# Initialization finished. Elapsed time:
# 0.011896133422851562
# 100%|██████████| 900/900 [00:00<00:00, 1148.38it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.8122391700744629
# Initialization finished. Elapsed time:
# 0.01417684555053711
# 100%|██████████| 900/900 [00:01<00:00, 648.04it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.4184131622314453
# Initialization finished. Elapsed time:
# 0.01212930679321289
# 100%|██████████| 900/900 [00:01<00:00, 700.47it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.3128950595855713
# Initialization finished. Elapsed time:
# 0.013684988021850586
# 100%|██████████| 900/900 [00:01<00:00, 676.61it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.352081298828125
# Initialization finished. Elapsed time:
# 0.018457412719726562
# 100%|██████████| 900/900 [00:01<00:00, 641.14it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.4393260478973389
# Initialization finished. Elapsed time:
# 0.017731904983520508
# 100%|██████████| 900/900 [00:01<00:00, 578.78it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.5913293361663818
# Initialization finished. Elapsed time:
# 0.015455245971679688
# 100%|██████████| 900/900 [00:02<00:00, 443.46it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 2.0667760372161865
# Initialization finished. Elapsed time:
# 0.02095341682434082
# 100%|██████████| 900/900 [00:01<00:00, 578.59it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.594778060913086
# Initialization finished. Elapsed time:
# 0.023957490921020508
# 100%|██████████| 900/900 [00:01<00:00, 716.20it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.2987749576568604
# Initialization finished. Elapsed time:
# 0.012160539627075195
# 100%|██████████| 900/900 [00:00<00:00, 994.16it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.9372470378875732
# Initialization finished. Elapsed time:
# 0.013934612274169922
# 100%|██████████| 900/900 [00:01<00:00, 757.98it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.2234981060028076
# Initialization finished. Elapsed time:
# 0.015562295913696289
# 100%|██████████| 900/900 [00:01<00:00, 730.40it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.2658724784851074
# Initialization finished. Elapsed time:
# 0.012746095657348633
# 100%|██████████| 900/900 [00:00<00:00, 1008.91it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.9217612743377686
# Initialization finished. Elapsed time:
# 0.012262582778930664
# 100%|██████████| 900/900 [00:00<00:00, 1030.91it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.8992249965667725
# Initialization finished. Elapsed time:
# 0.012468814849853516
# 100%|██████████| 900/900 [00:00<00:00, 1123.40it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.8269643783569336
# Initialization finished. Elapsed time:
# 0.012256622314453125
# 100%|██████████| 900/900 [00:00<00:00, 994.39it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.9315173625946045
# Initialization finished. Elapsed time:
# 0.012331485748291016
# 100%|██████████| 900/900 [00:00<00:00, 1124.04it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.8263740539550781
# Initialization finished. Elapsed time:
# 0.012452840805053711
# 100%|██████████| 900/900 [00:00<00:00, 1031.63it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.9013466835021973
# Initialization finished. Elapsed time:
# 0.018199682235717773
# 100%|██████████| 900/900 [00:01<00:00, 521.03it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.7640726566314697
# Initialization finished. Elapsed time:
# 0.014984846115112305
# 100%|██████████| 900/900 [00:00<00:00, 971.83it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.9581539630889893
# Initialization finished. Elapsed time:
# 0.012357950210571289
# 100%|██████████| 900/900 [00:01<00:00, 513.78it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.7792870998382568
# Initialization finished. Elapsed time:
# 0.013057708740234375
# 100%|██████████| 900/900 [00:00<00:00, 921.48it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.006875991821289
# Initialization finished. Elapsed time:
# 0.012428760528564453
# 100%|██████████| 900/900 [00:01<00:00, 667.72it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.382178783416748
# Initialization finished. Elapsed time:
# 0.016834020614624023
# 100%|██████████| 900/900 [00:00<00:00, 943.62it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.9787063598632812
# Initialization finished. Elapsed time:
# 0.012381315231323242
# 100%|██████████| 900/900 [00:00<00:00, 1075.50it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.8613734245300293
# Initialization finished. Elapsed time:
# 0.012349367141723633
# 100%|██████████| 900/900 [00:00<00:00, 903.41it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.0278055667877197
# Initialization finished. Elapsed time:
# 0.014154434204101562
# 100%|██████████| 900/900 [00:02<00:00, 444.31it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 2.061302661895752
# Initialization finished. Elapsed time:
# 0.014088869094848633
# 100%|██████████| 900/900 [00:01<00:00, 672.27it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.3678202629089355
# Initialization finished. Elapsed time:
# 0.01991868019104004
# 100%|██████████| 900/900 [00:01<00:00, 554.83it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.6587798595428467
# Initialization finished. Elapsed time:
# 0.015216827392578125
# 100%|██████████| 900/900 [00:01<00:00, 658.93it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.3870797157287598
# Initialization finished. Elapsed time:
# 0.016947507858276367
# 100%|██████████| 900/900 [00:01<00:00, 702.26it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.3192195892333984
# Initialization finished. Elapsed time:
# 0.012959480285644531
# 100%|██████████| 900/900 [00:01<00:00, 723.44it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.2747271060943604
# Initialization finished. Elapsed time:
# 0.015349149703979492
# 100%|██████████| 900/900 [00:01<00:00, 842.80it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.103205680847168
# Initialization finished. Elapsed time:
# 0.012790918350219727
# 100%|██████████| 900/900 [00:01<00:00, 729.41it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.262810468673706
# Initialization finished. Elapsed time:
# 0.014910459518432617
# 100%|██████████| 900/900 [00:01<00:00, 807.19it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.1498076915740967
# Initialization finished. Elapsed time:
# 0.012563228607177734
# 100%|██████████| 900/900 [00:00<00:00, 1046.14it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.8904600143432617
# Initialization finished. Elapsed time:
# 0.012599706649780273
# 100%|██████████| 900/900 [00:00<00:00, 986.70it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.942138671875
# Initialization finished. Elapsed time:
# 0.012629032135009766
# 100%|██████████| 900/900 [00:01<00:00, 618.80it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.4787821769714355
# Initialization finished. Elapsed time:
# 0.012419700622558594
# 100%|██████████| 900/900 [00:01<00:00, 585.67it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.5622737407684326
# Initialization finished. Elapsed time:
# 0.01291346549987793
# 100%|██████████| 900/900 [00:01<00:00, 895.37it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.0360634326934814
# Initialization finished. Elapsed time:
# 0.012420177459716797
# 100%|██████████| 900/900 [00:01<00:00, 743.05it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.2329132556915283
# Initialization finished. Elapsed time:
# 0.012227058410644531
# 100%|██████████| 900/900 [00:01<00:00, 517.51it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.7701587677001953
# Initialization finished. Elapsed time:
# 0.01798701286315918
# 100%|██████████| 900/900 [00:01<00:00, 679.84it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.3596138954162598
# Initialization finished. Elapsed time:
# 0.011941194534301758
# 100%|██████████| 900/900 [00:01<00:00, 668.11it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.3756210803985596
# Initialization finished. Elapsed time:
# 0.014025211334228516
# 100%|██████████| 900/900 [00:01<00:00, 747.59it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.2349839210510254
# Initialization finished. Elapsed time:
# 0.013242006301879883
# 100%|██████████| 900/900 [00:00<00:00, 1006.43it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.9178023338317871
# Initialization finished. Elapsed time:
# 0.012174844741821289
# 100%|██████████| 900/900 [00:00<00:00, 952.58it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.9767165184020996
# Initialization finished. Elapsed time:
# 0.01186513900756836
# 100%|██████████| 900/900 [00:00<00:00, 1028.97it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.9065961837768555
# Initialization finished. Elapsed time:
# 0.024851560592651367
# 100%|██████████| 900/900 [00:01<00:00, 599.09it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.5399303436279297
# Initialization finished. Elapsed time:
# 0.017409563064575195
# 100%|██████████| 900/900 [00:02<00:00, 444.92it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 2.0604195594787598
# Initialization finished. Elapsed time:
# 0.028575420379638672
# 100%|██████████| 900/900 [00:00<00:00, 915.31it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.0281429290771484
# Initialization finished. Elapsed time:
# 0.012449264526367188
# 100%|██████████| 900/900 [00:00<00:00, 1103.66it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.8450644016265869
# Initialization finished. Elapsed time:
# 0.01235818862915039
# 100%|██████████| 900/900 [00:01<00:00, 621.87it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.4782001972198486
# Initialization finished. Elapsed time:
# 0.01578545570373535
# 100%|██████████| 900/900 [00:00<00:00, 1012.20it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.9235620498657227
# Initialization finished. Elapsed time:
# 0.015392065048217773
# 100%|██████████| 900/900 [00:01<00:00, 682.80it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.351365327835083
# Initialization finished. Elapsed time:
# 0.012420177459716797
# 100%|██████████| 900/900 [00:00<00:00, 1076.50it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.8585538864135742
# Initialization finished. Elapsed time:
# 0.012196540832519531
# 100%|██████████| 900/900 [00:00<00:00, 1087.32it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.8526933193206787
# Initialization finished. Elapsed time:
# 0.012297391891479492
# 100%|██████████| 900/900 [00:00<00:00, 1137.86it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.814953088760376
# Initialization finished. Elapsed time:
# 0.01488494873046875
# 100%|██████████| 900/900 [00:00<00:00, 914.89it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.017225980758667
# Initialization finished. Elapsed time:
# 0.01234126091003418
# 100%|██████████| 900/900 [00:00<00:00, 1137.91it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.8166747093200684
# Initialization finished. Elapsed time:
# 0.012468099594116211
# 100%|██████████| 900/900 [00:01<00:00, 825.31it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.113435983657837
# Initialization finished. Elapsed time:
# 0.015720129013061523
# 100%|██████████| 900/900 [00:01<00:00, 744.40it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.2338709831237793
# Initialization finished. Elapsed time:
# 0.014467954635620117
# 100%|██████████| 900/900 [00:01<00:00, 785.21it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.1811487674713135
# Initialization finished. Elapsed time:
# 0.020398378372192383
# 100%|██████████| 900/900 [00:01<00:00, 738.13it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.2500193119049072
# Initialization finished. Elapsed time:
# 0.014244794845581055
# 100%|██████████| 900/900 [00:01<00:00, 661.76it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.3948309421539307
# Initialization finished. Elapsed time:
# 0.013659238815307617
# 100%|██████████| 900/900 [00:01<00:00, 490.86it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.8650672435760498
# Initialization finished. Elapsed time:
# 0.012246131896972656
# 100%|██████████| 900/900 [00:00<00:00, 1127.17it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.8230786323547363
# Initialization finished. Elapsed time:
# 0.012156963348388672
# 100%|██████████| 900/900 [00:00<00:00, 1007.68it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.9239416122436523
# Initialization finished. Elapsed time:
# 0.012225151062011719
# 100%|██████████| 900/900 [00:00<00:00, 1134.65it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.8239932060241699
# Initialization finished. Elapsed time:
# 0.012207746505737305
# 100%|██████████| 900/900 [00:00<00:00, 1094.14it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.8426263332366943
# Initialization finished. Elapsed time:
# 0.012293338775634766
# 100%|██████████| 900/900 [00:01<00:00, 628.10it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.4540648460388184
# Initialization finished. Elapsed time:
# 0.012313604354858398
# 100%|██████████| 900/900 [00:01<00:00, 728.47it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.2587757110595703
# Initialization finished. Elapsed time:
# 0.015096902847290039
# 100%|██████████| 900/900 [00:00<00:00, 1091.17it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.8472261428833008
# Initialization finished. Elapsed time:
# 0.012274980545043945
# 100%|██████████| 900/900 [00:01<00:00, 859.41it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.0764825344085693
# Initialization finished. Elapsed time:
# 0.01531529426574707
# 100%|██████████| 900/900 [00:01<00:00, 816.08it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.1278305053710938
# Initialization finished. Elapsed time:
# 0.012130975723266602
# 100%|██████████| 900/900 [00:00<00:00, 1099.91it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.8418483734130859
# Initialization finished. Elapsed time:
# 0.01217961311340332
# 100%|██████████| 900/900 [00:00<00:00, 1144.90it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.8154861927032471
# Initialization finished. Elapsed time:
# 0.01507878303527832
# 100%|██████████| 900/900 [00:01<00:00, 686.11it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.3452060222625732
# Initialization finished. Elapsed time:
# 0.012689352035522461
# 100%|██████████| 900/900 [00:00<00:00, 1134.25it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.8131325244903564
# Initialization finished. Elapsed time:
# 0.01224207878112793
# 100%|██████████| 900/900 [00:01<00:00, 693.39it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.3226122856140137
# Initialization finished. Elapsed time:
# 0.014915227890014648
# 100%|██████████| 900/900 [00:00<00:00, 1136.15it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.8172554969787598
# Initialization finished. Elapsed time:
# 0.012062788009643555
# 100%|██████████| 900/900 [00:00<00:00, 1091.99it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 0.8536257743835449
# Initialization finished. Elapsed time:
# 0.012150287628173828
# 100%|██████████| 900/900 [00:01<00:00, 689.35it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.336045265197754
# Initialization finished. Elapsed time:
# 0.012854814529418945
# 100%|██████████| 900/900 [00:01<00:00, 709.31it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.2958972454071045
# Initialization finished. Elapsed time:
# 0.018093347549438477
# 100%|██████████| 900/900 [00:01<00:00, 637.41it/s]
# (1, 900, 1824)
# Iterations finished. Elapsed time:
# 1.442370891571045
# Testing finished. Elapsed time:
# 121.70955562591553
# Testing finished. Elapsed time:
# 1.3134236335754395
# Testing score:
# -1.9378164855932085

# %%
pred_output[200,:]
# Out:
# array([0.12440249, 0.21784067, 0.24674587, 0.24125618, 0.23512229,
#        0.24196603, 0.23914373, 0.23536769, 0.23668166, 0.23847969,
#        0.23690367, 0.23615563, 0.24067846, 0.23689746, 0.23650032,
#        0.23103327, 0.23365197, 0.24142114, 0.23624475, 0.23105992,
#        0.23381148, 0.24119349, 0.2383155 , 0.23182739, 0.23253084,
#        0.23829453, 0.23774724, 0.23299118, 0.23015301, 0.23325702,
#        0.23737901, 0.23613865, 0.23128435, 0.23387453, 0.23937668,
#        0.23329698, 0.23744185, 0.23251153, 0.23379864, 0.23537056,
#        0.23011522, 0.23550996, 0.24123519, 0.23276457, 0.23143238,
#        0.23049941, 0.24099576, 0.23750354, 0.23542141, 0.23668236,
#        0.23553179, 0.23184996, 0.2349722 , 0.23408487, 0.23633079,
#        0.2334077 , 0.23599577, 0.23874322, 0.23332062, 0.23359043,
#        0.23895905, 0.23659519, 0.23535915, 0.23302903, 0.23403565,
#        0.23557804, 0.231613  , 0.23576918, 0.23934242, 0.23602484,
#        0.23243454, 0.22902106, 0.23786273, 0.2329144 , 0.23416247,
#        0.23683584, 0.24049214, 0.23096107, 0.23387802, 0.23436587,
#        0.2360237 , 0.23585142, 0.23533711, 0.232662  , 0.23820087,
#        0.23689299, 0.23228216, 0.23496545, 0.24033667, 0.23791284,
#        0.23326251, 0.23517667, 0.23282713, 0.23480292, 0.23709907,
#        0.2360704 , 0.23645156, 0.23368647, 0.23655449, 0.23474458])

# %%
# n_input = round(pred_output.shape[0]/2)-100
n_input = 200
all_data = np.concatenate((y[:n_input, 0], pred_output[n_input, :total_pred_steps]))
plt.figure(1)
plt.plot(all_data)
plt.plot(y[0:n_input+total_pred_steps, 0])
plt.show()
plt.figure(2)
plt.plot(y[0:n_input+total_pred_steps, 0]-all_data)
# plt.plot(np.linspace(n_input,n_input,100),np.linspace(-0.6,0.6,100))
plt.show()

# %%
# maximum first 5 prediction steps are illustrated 
pred_step = min(5, y.shape[-1])
fig, axs = plt.subplots(pred_step, 1, sharex=True, figsize=(10,10))
fig.subplots_adjust(hspace=0)
for i in range(pred_step):
    axs[i].plot(y[:,i])
    axs[i].plot(pred_output[:,i])
plt.show()

# %%
# rms for binary encoding

length_input = pred_output.shape[0]-total_pred_steps
rms = np.zeros((length_input, total_pred_steps))
for n_input in range(1, length_input):
    for n_pred in range(1, total_pred_steps):
        d1 = pred_output[n_input, :n_pred]
        d2 = y[n_input:n_input+n_pred, 0]
        rms[n_input, n_pred] = np.sqrt(1./(n_pred)*np.sum((d1 - d2)**2))

plt.figure(1,figsize=(10,2))
plt.title('rms')
plt.ylabel('input length')
plt.xlabel('Prediction length')
im=plt.pcolormesh(rms[:,:], cmap='gist_heat')
plt.colorbar(im)
plt.show;

plt.figure(2,figsize=(8.1,2))
plt.ylabel('average rms by input length')
plt.xlabel('Prediction length')
plt.plot(np.sum(rms[:,:], axis=0)/length_input)
plt.show;

# %%
plt.figure(2,figsize=(8.1,2))
plt.ylabel('average rms by input length')
plt.xlabel('Prediction length')
plt.plot(np.sum(rms[1:,:], axis=1)/total_pred_steps)
plt.show;
