# %%
#!/usr/bin/python

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

# import os
# import sys
import numpy as np

import time

from reservoir import Reservoir
import data

# %load_ext autoreload
# %autoreload 1
# %aimport data
# %aimport reservoir

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
total_pred_steps = 100
spatial_points = 64
enc_depth = 6
n_res = 1000
b = Reservoir(n_res=n_res, input_scale=2, train_method='ridge', train_param=2000,
              weights_type='complex gaussian', random_projection='simulation',
              activation_fun='binary', activation_param=1,encoding_method='naivebinary', 
              encoding_param=1, encoded_spatial_points=(2**enc_depth)*spatial_points, forget=100, 
              total_pred_steps = total_pred_steps, each_pred_step = 1) 
# if DMD: encoded_spatial_points = (2**enc_depth)*spatial_points 
# if SLM: encoded_spatial_points = spatial_points+1

# %%
input_data = data.mackey_glass(sequence_length=4000)
y = data.roll_and_concat(input_data, roll_num=1)
# input_data = input_data[:,:-roll_num,:]
# y = y[:,:-roll_num,:]
b.fit(input_data, y)
# Out:
# Start of training...
# Initialization finished. Elapsed time:
# 0.20202350616455078
# 100%|██████████| 4000/4000 [00:14<00:00, 269.45it/s]
# Iterations finished. Elapsed time:
# 15.162079334259033
# Training finished. Elapsed time:
# 17.522650480270386
# Training score:
# 0.9877370792142051
# Reservoir(activation_fun='binary', activation_param=1, each_pred_step=1,
#      encoded_spatial_points=4096, encoding_method='naivebinary',
#      encoding_param=1, forget=100, input_scale=2, n_res=1000,
#      opu_transform=None, random_projection='simulation',
#      random_state=<mtrand.RandomState object at 0x7f464c085990>,
#      res_scale=1, save=0, total_pred_steps=100, train_method='ridge',
#      train_param=2000, verbose=1, weights_type='complex gaussian')

# %%
input_data = data.mackey_glass(sequence_length=1000)
y = data.roll_and_concat(input_data, roll_num=total_pred_steps)[:, b.forget:, :]
y = y.reshape(-1, y.shape[-1])
pred_output, valid_score = b.score(input_data, y)
# Out:
# Start of testing...
# Initialization finished. Elapsed time:
# 0.04765462875366211
# 100%|██████████| 1000/1000 [00:03<00:00, 252.67it/s]
# Iterations finished. Elapsed time:
# 4.044336557388306
# Initialization finished. Elapsed time:
# 0.05046677589416504
# 100%|██████████| 900/900 [00:03<00:00, 280.04it/s]
# Iterations finished. Elapsed time:
# 3.4062132835388184
# Initialization finished. Elapsed time:
# 0.07484674453735352
# 100%|██████████| 900/900 [00:04<00:00, 220.92it/s]
# Iterations finished. Elapsed time:
# 4.196236848831177
# Initialization finished. Elapsed time:
# 0.0496516227722168
# 100%|██████████| 900/900 [00:03<00:00, 283.36it/s]
# Iterations finished. Elapsed time:
# 3.2603375911712646
# Initialization finished. Elapsed time:
# 0.05160975456237793
# 100%|██████████| 900/900 [00:02<00:00, 303.38it/s]
# Iterations finished. Elapsed time:
# 3.06795597076416
# Initialization finished. Elapsed time:
# 0.05138421058654785
# 100%|██████████| 900/900 [00:03<00:00, 289.02it/s]
# Iterations finished. Elapsed time:
# 3.201228618621826
# Initialization finished. Elapsed time:
# 0.04850149154663086
# 100%|██████████| 900/900 [00:03<00:00, 274.03it/s]
# Iterations finished. Elapsed time:
# 3.3709824085235596
# Initialization finished. Elapsed time:
# 0.05106544494628906
# 100%|██████████| 900/900 [00:03<00:00, 287.38it/s]
# Iterations finished. Elapsed time:
# 3.21766996383667
# Initialization finished. Elapsed time:
# 0.05202293395996094
# 100%|██████████| 900/900 [00:03<00:00, 232.70it/s]
# Iterations finished. Elapsed time:
# 3.9573898315429688
# Initialization finished. Elapsed time:
# 0.06552267074584961
# 100%|██████████| 900/900 [00:03<00:00, 226.33it/s]
# Iterations finished. Elapsed time:
# 4.080077409744263
# Initialization finished. Elapsed time:
# 0.048722267150878906
# 100%|██████████| 900/900 [00:03<00:00, 266.75it/s]
# Iterations finished. Elapsed time:
# 3.4630699157714844
# Initialization finished. Elapsed time:
# 0.050037384033203125
# 100%|██████████| 900/900 [00:04<00:00, 217.59it/s]
# Iterations finished. Elapsed time:
# 4.261083364486694
# Initialization finished. Elapsed time:
# 0.05642294883728027
# 100%|██████████| 900/900 [00:03<00:00, 276.02it/s]
# Iterations finished. Elapsed time:
# 3.3574838638305664
# Initialization finished. Elapsed time:
# 0.050573110580444336
# 100%|██████████| 900/900 [00:04<00:00, 191.43it/s]
# Iterations finished. Elapsed time:
# 4.786515951156616
# Initialization finished. Elapsed time:
# 0.05673074722290039
# 100%|██████████| 900/900 [00:04<00:00, 216.28it/s]
# Iterations finished. Elapsed time:
# 4.25261378288269
# Initialization finished. Elapsed time:
# 0.04760551452636719
# 100%|██████████| 900/900 [00:03<00:00, 298.50it/s]
# Iterations finished. Elapsed time:
# 3.096359968185425
# Initialization finished. Elapsed time:
# 0.04919719696044922
# 100%|██████████| 900/900 [00:03<00:00, 299.55it/s]
# Iterations finished. Elapsed time:
# 3.085937261581421
# Initialization finished. Elapsed time:
# 0.049015045166015625
# 100%|██████████| 900/900 [00:02<00:00, 301.57it/s]
# Iterations finished. Elapsed time:
# 3.067248582839966
# Initialization finished. Elapsed time:
# 0.05167889595031738
# 100%|██████████| 900/900 [00:03<00:00, 296.83it/s]
# Iterations finished. Elapsed time:
# 3.1202125549316406
# Initialization finished. Elapsed time:
# 0.04910111427307129
# 100%|██████████| 900/900 [00:03<00:00, 267.05it/s]
# Iterations finished. Elapsed time:
# 3.453390598297119
# Initialization finished. Elapsed time:
# 0.049016475677490234
# 100%|██████████| 900/900 [00:03<00:00, 290.97it/s]
# Iterations finished. Elapsed time:
# 3.179107427597046
# Initialization finished. Elapsed time:
# 0.048703670501708984
# 100%|██████████| 900/900 [00:03<00:00, 277.49it/s]
# Iterations finished. Elapsed time:
# 3.327768325805664
# Initialization finished. Elapsed time:
# 0.06047368049621582
# 100%|██████████| 900/900 [00:03<00:00, 281.63it/s]
# Iterations finished. Elapsed time:
# 3.297574996948242
# Initialization finished. Elapsed time:
# 0.04895734786987305
# 100%|██████████| 900/900 [00:03<00:00, 280.91it/s]
# Iterations finished. Elapsed time:
# 3.2924702167510986
# Initialization finished. Elapsed time:
# 0.05229043960571289
# 100%|██████████| 900/900 [00:03<00:00, 284.98it/s]
# Iterations finished. Elapsed time:
# 3.26064395904541
# Initialization finished. Elapsed time:
# 0.05226755142211914
# 100%|██████████| 900/900 [00:03<00:00, 282.55it/s]
# Iterations finished. Elapsed time:
# 3.276139974594116
# Initialization finished. Elapsed time:
# 0.05204510688781738
# 100%|██████████| 900/900 [00:03<00:00, 292.32it/s]
# Iterations finished. Elapsed time:
# 3.171318531036377
# Initialization finished. Elapsed time:
# 0.05288553237915039
# 100%|██████████| 900/900 [00:05<00:00, 160.30it/s]
# Iterations finished. Elapsed time:
# 5.715071678161621
# Initialization finished. Elapsed time:
# 0.05838632583618164
# 100%|██████████| 900/900 [00:05<00:00, 170.29it/s]
# Iterations finished. Elapsed time:
# 5.375355958938599
# Initialization finished. Elapsed time:
# 0.05706167221069336
# 100%|██████████| 900/900 [00:03<00:00, 247.31it/s]
# Iterations finished. Elapsed time:
# 3.7329587936401367
# Initialization finished. Elapsed time:
# 0.04896187782287598
# 100%|██████████| 900/900 [00:03<00:00, 275.91it/s]
# Iterations finished. Elapsed time:
# 3.3524491786956787
# Initialization finished. Elapsed time:
# 0.04869508743286133
# 100%|██████████| 900/900 [00:03<00:00, 235.98it/s]
# Iterations finished. Elapsed time:
# 3.8961145877838135
# Initialization finished. Elapsed time:
# 0.056879281997680664
# 100%|██████████| 900/900 [00:03<00:00, 291.33it/s]
# Iterations finished. Elapsed time:
# 3.2019641399383545
# Initialization finished. Elapsed time:
# 0.05319499969482422
# 100%|██████████| 900/900 [00:04<00:00, 216.63it/s]
# Iterations finished. Elapsed time:
# 4.239473581314087
# Initialization finished. Elapsed time:
# 0.050217628479003906
# 100%|██████████| 900/900 [00:03<00:00, 249.23it/s]
# Iterations finished. Elapsed time:
# 3.7056877613067627
# Initialization finished. Elapsed time:
# 0.05217552185058594
# 100%|██████████| 900/900 [00:04<00:00, 187.21it/s]
# Iterations finished. Elapsed time:
# 4.900721311569214
# Initialization finished. Elapsed time:
# 0.060741424560546875
# 100%|██████████| 900/900 [00:04<00:00, 182.83it/s]
# Iterations finished. Elapsed time:
# 5.019218921661377
# Initialization finished. Elapsed time:
# 0.05119824409484863
# 100%|██████████| 900/900 [00:03<00:00, 190.98it/s]
# Iterations finished. Elapsed time:
# 4.098886251449585
# Initialization finished. Elapsed time:
# 0.06362462043762207
# 100%|██████████| 900/900 [00:03<00:00, 225.51it/s]
# Iterations finished. Elapsed time:
# 4.093000650405884
# Initialization finished. Elapsed time:
# 0.06219339370727539
# 100%|██████████| 900/900 [00:04<00:00, 215.38it/s]
# Iterations finished. Elapsed time:
# 4.2820351123809814
# Initialization finished. Elapsed time:
# 0.05923104286193848
# 100%|██████████| 900/900 [00:04<00:00, 199.31it/s]
# Iterations finished. Elapsed time:
# 4.607662677764893
# Initialization finished. Elapsed time:
# 0.051204681396484375
# 100%|██████████| 900/900 [00:03<00:00, 258.40it/s]
# Iterations finished. Elapsed time:
# 3.574631929397583
# Initialization finished. Elapsed time:
# 0.04829263687133789
# 100%|██████████| 900/900 [00:03<00:00, 290.24it/s]
# Iterations finished. Elapsed time:
# 3.187387704849243
# Initialization finished. Elapsed time:
# 0.05165219306945801
# 100%|██████████| 900/900 [00:04<00:00, 216.71it/s]
# Iterations finished. Elapsed time:
# 4.241448879241943
# Initialization finished. Elapsed time:
# 0.05330228805541992
# 100%|██████████| 900/900 [00:03<00:00, 291.51it/s]
# Iterations finished. Elapsed time:
# 3.1763699054718018
# Initialization finished. Elapsed time:
# 0.05610203742980957
# 100%|██████████| 900/900 [00:04<00:00, 212.17it/s]
# Iterations finished. Elapsed time:
# 4.360785245895386
# Initialization finished. Elapsed time:
# 0.05602240562438965
# 100%|██████████| 900/900 [00:03<00:00, 288.33it/s]
# Iterations finished. Elapsed time:
# 3.214046001434326
# Initialization finished. Elapsed time:
# 0.059053659439086914
# 100%|██████████| 900/900 [00:03<00:00, 263.26it/s]
# Iterations finished. Elapsed time:
# 3.518092155456543
# Initialization finished. Elapsed time:
# 0.051485300064086914
# 100%|██████████| 900/900 [00:03<00:00, 290.32it/s]
# Iterations finished. Elapsed time:
# 3.1941347122192383
# Initialization finished. Elapsed time:
# 0.052410125732421875
# 100%|██████████| 900/900 [00:04<00:00, 192.00it/s]
# Iterations finished. Elapsed time:
# 4.787080764770508
# Initialization finished. Elapsed time:
# 0.05908489227294922
# 100%|██████████| 900/900 [00:04<00:00, 211.41it/s]
# Iterations finished. Elapsed time:
# 4.364957571029663
# Initialization finished. Elapsed time:
# 0.09161829948425293
# 100%|██████████| 900/900 [00:05<00:00, 167.85it/s]
# Iterations finished. Elapsed time:
# 5.4914233684539795
# Initialization finished. Elapsed time:
# 0.0552065372467041
# 100%|██████████| 900/900 [00:03<00:00, 248.84it/s]
# Iterations finished. Elapsed time:
# 3.7109475135803223
# Initialization finished. Elapsed time:
# 0.051209211349487305
# 100%|██████████| 900/900 [00:04<00:00, 198.02it/s]
# Iterations finished. Elapsed time:
# 4.631008148193359
# Initialization finished. Elapsed time:
# 0.06022071838378906
# 100%|██████████| 900/900 [00:03<00:00, 248.71it/s]
# Iterations finished. Elapsed time:
# 4.09546422958374
# Initialization finished. Elapsed time:
# 0.04944896697998047
# 100%|██████████| 900/900 [00:04<00:00, 215.79it/s]
# Iterations finished. Elapsed time:
# 4.2641825675964355
# Initialization finished. Elapsed time:
# 0.053954362869262695
# 100%|██████████| 900/900 [00:03<00:00, 237.72it/s]
# Iterations finished. Elapsed time:
# 3.898974895477295
# Initialization finished. Elapsed time:
# 0.05413818359375
# 100%|██████████| 900/900 [00:05<00:00, 158.31it/s]
# Iterations finished. Elapsed time:
# 5.792090654373169
# Initialization finished. Elapsed time:
# 0.06703376770019531
# 100%|██████████| 900/900 [00:05<00:00, 174.81it/s]
# Iterations finished. Elapsed time:
# 5.25849461555481
# Initialization finished. Elapsed time:
# 0.04951310157775879
# 100%|██████████| 900/900 [00:04<00:00, 198.65it/s]
# Iterations finished. Elapsed time:
# 4.6220338344573975
# Initialization finished. Elapsed time:
# 0.05211901664733887
# 100%|██████████| 900/900 [00:04<00:00, 189.38it/s]
# Iterations finished. Elapsed time:
# 4.837405681610107
# Initialization finished. Elapsed time:
# 0.05147051811218262
# 100%|██████████| 900/900 [00:03<00:00, 294.38it/s]
# Iterations finished. Elapsed time:
# 3.6974422931671143
# Initialization finished. Elapsed time:
# 0.05196857452392578
# 100%|██████████| 900/900 [00:04<00:00, 180.08it/s]
# Iterations finished. Elapsed time:
# 5.103104114532471
# Initialization finished. Elapsed time:
# 0.05678868293762207
# 100%|██████████| 900/900 [00:04<00:00, 187.02it/s]
# Iterations finished. Elapsed time:
# 4.901815176010132
# Initialization finished. Elapsed time:
# 0.05166053771972656
# 100%|██████████| 900/900 [00:03<00:00, 248.37it/s]
# Iterations finished. Elapsed time:
# 3.7142486572265625
# Initialization finished. Elapsed time:
# 0.052115678787231445
# 100%|██████████| 900/900 [00:04<00:00, 204.84it/s]
# Iterations finished. Elapsed time:
# 4.488042593002319
# Initialization finished. Elapsed time:
# 0.057650089263916016
# 100%|██████████| 900/900 [00:03<00:00, 231.19it/s]
# Iterations finished. Elapsed time:
# 3.9919536113739014
# Initialization finished. Elapsed time:
# 0.04920792579650879
# 100%|██████████| 900/900 [00:03<00:00, 250.31it/s]
# Iterations finished. Elapsed time:
# 3.6868162155151367
# Initialization finished. Elapsed time:
# 0.08247971534729004
# 100%|██████████| 900/900 [00:05<00:00, 179.47it/s]
# Iterations finished. Elapsed time:
# 5.135411739349365
# Initialization finished. Elapsed time:
# 0.05289769172668457
# 100%|██████████| 900/900 [00:03<00:00, 267.17it/s]
# Iterations finished. Elapsed time:
# 3.454604387283325
# Initialization finished. Elapsed time:
# 0.04842233657836914
# 100%|██████████| 900/900 [00:03<00:00, 252.19it/s]
# Iterations finished. Elapsed time:
# 3.650322437286377
# Initialization finished. Elapsed time:
# 0.04841756820678711
# 100%|██████████| 900/900 [00:03<00:00, 248.52it/s]
# Iterations finished. Elapsed time:
# 3.704214096069336
# Initialization finished. Elapsed time:
# 0.04858279228210449
# 100%|██████████| 900/900 [00:04<00:00, 188.11it/s]
# Iterations finished. Elapsed time:
# 4.865593433380127
# Initialization finished. Elapsed time:
# 0.05961108207702637
# 100%|██████████| 900/900 [00:03<00:00, 268.24it/s]
# Iterations finished. Elapsed time:
# 3.4501113891601562
# Initialization finished. Elapsed time:
# 0.05501127243041992
# 100%|██████████| 900/900 [00:03<00:00, 278.91it/s]
# Iterations finished. Elapsed time:
# 3.3154993057250977
# Initialization finished. Elapsed time:
# 0.048970937728881836
# 100%|██████████| 900/900 [00:03<00:00, 293.33it/s]
# Iterations finished. Elapsed time:
# 3.159501791000366
# Initialization finished. Elapsed time:
# 0.04890751838684082
# 100%|██████████| 900/900 [00:03<00:00, 240.54it/s]
# Iterations finished. Elapsed time:
# 3.843000650405884
# Initialization finished. Elapsed time:
# 0.04623556137084961
# 100%|██████████| 900/900 [00:04<00:00, 195.05it/s]
# Iterations finished. Elapsed time:
# 4.703296899795532
# Initialization finished. Elapsed time:
# 0.04818415641784668
# 100%|██████████| 900/900 [00:04<00:00, 220.36it/s]
# Iterations finished. Elapsed time:
# 4.165429592132568
# Initialization finished. Elapsed time:
# 0.04871416091918945
# 100%|██████████| 900/900 [00:04<00:00, 199.40it/s]
# Iterations finished. Elapsed time:
# 4.618181228637695
# Initialization finished. Elapsed time:
# 0.0623321533203125
# 100%|██████████| 900/900 [00:06<00:00, 146.95it/s]
# Iterations finished. Elapsed time:
# 6.237744331359863
# Initialization finished. Elapsed time:
# 0.05732321739196777
# 100%|██████████| 900/900 [00:05<00:00, 164.92it/s]
# Iterations finished. Elapsed time:
# 5.550183057785034
# Initialization finished. Elapsed time:
# 0.05177044868469238
# 100%|██████████| 900/900 [00:03<00:00, 243.08it/s]
# Iterations finished. Elapsed time:
# 3.8009400367736816
# Initialization finished. Elapsed time:
# 0.05254054069519043
# 100%|██████████| 900/900 [00:04<00:00, 183.71it/s]
# Iterations finished. Elapsed time:
# 4.994195461273193
# Initialization finished. Elapsed time:
# 0.05360579490661621
# 100%|██████████| 900/900 [00:03<00:00, 233.10it/s]
# Iterations finished. Elapsed time:
# 3.9528725147247314
# Initialization finished. Elapsed time:
# 0.051849365234375
# 100%|██████████| 900/900 [00:04<00:00, 207.34it/s]
# Iterations finished. Elapsed time:
# 4.436284780502319
# Initialization finished. Elapsed time:
# 0.06746506690979004
# 100%|██████████| 900/900 [00:05<00:00, 160.11it/s]
# Iterations finished. Elapsed time:
# 5.7510457038879395
# Initialization finished. Elapsed time:
# 0.07246732711791992
# 100%|██████████| 900/900 [00:04<00:00, 197.42it/s]
# Iterations finished. Elapsed time:
# 4.6661601066589355
# Initialization finished. Elapsed time:
# 0.048670291900634766
# 100%|██████████| 900/900 [00:04<00:00, 196.97it/s]
# Iterations finished. Elapsed time:
# 4.654233694076538
# Initialization finished. Elapsed time:
# 0.059736013412475586
# 100%|██████████| 900/900 [00:04<00:00, 200.66it/s]
# Iterations finished. Elapsed time:
# 4.586909294128418
# Initialization finished. Elapsed time:
# 0.048674583435058594
# 100%|██████████| 900/900 [00:04<00:00, 204.43it/s]
# Iterations finished. Elapsed time:
# 4.4933459758758545
# Initialization finished. Elapsed time:
# 0.05150246620178223
# 100%|██████████| 900/900 [00:03<00:00, 228.80it/s]
# Iterations finished. Elapsed time:
# 4.029324054718018
# Initialization finished. Elapsed time:
# 0.06202387809753418
# 100%|██████████| 900/900 [00:04<00:00, 193.14it/s]
# Iterations finished. Elapsed time:
# 4.7594895362854
# Initialization finished. Elapsed time:
# 0.049071550369262695
# 100%|██████████| 900/900 [00:03<00:00, 279.89it/s]
# Iterations finished. Elapsed time:
# 3.823089838027954
# Initialization finished. Elapsed time:
# 0.05180168151855469
# 100%|██████████| 900/900 [00:04<00:00, 182.03it/s]
# Iterations finished. Elapsed time:
# 5.031482934951782
# Initialization finished. Elapsed time:
# 0.05348491668701172
# 100%|██████████| 900/900 [00:04<00:00, 192.15it/s]
# Iterations finished. Elapsed time:
# 4.782216310501099
# Initialization finished. Elapsed time:
# 0.05318307876586914
# 100%|██████████| 900/900 [00:04<00:00, 181.84it/s]
# Iterations finished. Elapsed time:
# 5.033777952194214
# Initialization finished. Elapsed time:
# 0.05014157295227051
# 100%|██████████| 900/900 [00:05<00:00, 175.13it/s]
# Iterations finished. Elapsed time:
# 5.223473787307739
# Initialization finished. Elapsed time:
# 0.0519711971282959
# 100%|██████████| 900/900 [00:04<00:00, 180.34it/s]
# Iterations finished. Elapsed time:
# 5.105103492736816
# Initialization finished. Elapsed time:
# 0.06357455253601074
# 100%|██████████| 900/900 [00:04<00:00, 212.69it/s]
# Iterations finished. Elapsed time:
# 4.33181357383728
# Testing finished. Elapsed time:
# 416.7197940349579
# Testing finished. Elapsed time:
# 17.522650480270386
# Testing score:
# -2.8822349306961774

# %%
# n_input = round(pred_output.shape[0]/2)-100
n_input = 100
all_data = np.concatenate((y[0:n_input, 0], pred_output[n_input, :total_pred_steps]))
plt.figure(1)
plt.plot(all_data)
plt.plot(y[0:n_input+total_pred_steps, 0])
plt.show()
plt.figure(2)
plt.plot(y[0:n_input+total_pred_steps, 0]-all_data)
# plt.plot(np.linspace(n_input,n_input,100),np.linspace(-0.6,0.6,100))
plt.show()

# %%
# maximum first 5 prediction steps are illustrated 
pred_step = min(5, y.shape[-1])
fig, axs = plt.subplots(pred_step, 1, sharex=True, figsize=(10,10))
fig.subplots_adjust(hspace=0)
for i in range(pred_step):
    axs[i].plot(y[:,i])
    axs[i].plot(pred_output[:,i])
plt.show()

# %%
# rms for binary encoding

length_input = pred_output.shape[0]-total_pred_steps
rms = np.zeros((length_input, total_pred_steps))
for n_input in range(1, length_input):
    for n_pred in range(1, total_pred_steps):
        d1 = pred_output[n_input, :n_pred]
        d2 = y[n_input:n_input+n_pred, 0]
        rms[n_input, n_pred] = np.sqrt(1./(n_pred)*np.sum((d1 - d2)**2))

plt.figure(1,figsize=(10,2))
plt.title('rms for binary encoding (10 bit)')
plt.ylabel('input length')
plt.xlabel('Prediction length')
im=plt.pcolormesh(rms[:,:], cmap='gist_heat')
plt.colorbar(im)
plt.show;

plt.figure(2,figsize=(8.1,2))
plt.ylabel('average rms by input length')
plt.xlabel('Prediction length')
plt.plot(np.sum(rms[:,:], axis=0)/length_input)
plt.show;

# %%
# rms for phase encoding

length_input = pred_output.shape[0]-total_pred_steps
rms = np.zeros((length_input, total_pred_steps))
for n_input in range(1, length_input):
    for n_pred in range(1, total_pred_steps):
        d1 = pred_output[n_input, :n_pred]
        d2 = y[n_input:n_input+n_pred, 0]
        rms[n_input, n_pred] = np.sqrt(1./(n_pred)*np.sum((d1 - d2)**2))

plt.figure(1,figsize=(10,2))
plt.title('rms for phase encoding (8 bit)')
plt.ylabel('input length')
plt.xlabel('Prediction length')
im=plt.pcolormesh(rms[1:,1:], cmap='gist_heat')
plt.colorbar(im)
plt.show;

plt.figure(2,figsize=(8.1,2))
plt.ylabel('average rms by input length')
plt.xlabel('Prediction length')
plt.plot(np.sum(rms[1:,1:], axis=0)/length_input)
plt.show;

# %%
plt.figure(2,figsize=(8.1,2))
plt.ylabel('average rms by input length')
plt.xlabel('Prediction length')
plt.plot(np.sum(rms[1:,:], axis=1)/total_pred_steps)
plt.show;
